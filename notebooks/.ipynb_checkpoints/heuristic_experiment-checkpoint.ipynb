# %%
import json
import scipy
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from functools import cmp_to_key
import copy

sns.set_theme(font='Fira Code', font_scale=0.8, style='whitegrid')
sns.set_style({'grid.linestyle': ':'})

import warnings
warnings.filterwarnings('ignore')

# %%
def get_filename(crawl, climb, size, mass, count):
    return f'../data/crawl_{crawl}_climb_{climb}_size_{size}_mass_{mass}_cnt_{count}.json';

# %%
crawl, climb, size, mass, count = '0.2', '0.2', '0', '0', 100
filename = get_filename(crawl, climb, size, mass, count)
with open(filename, 'r') as file:
        data = json.load(file)
points = data['points']

# %%
def equal(a, b):
    return a['x'] == b['x'] and a['y'] == b['y']

# %%
def orientation(a, b, c):
    v = a['x']*(b['y']-c['y']) + b['x']*(c['y']-a['y']) + c['x']*(a['y']-b['y'])
    if v < 0:
        return -1
    if v > 0:
        return 1
    return 0;

# %%
def get_boundary_alt(a_raw, thresh_base = 30, error_y = 10):
    a = a_raw[::]
    
    def compare(p1, p2):
        if p1['x'] == p2['x']:
            return p1['y'] - p2['y']
        return p1['x'] - p2['x']

    def get_dist(p1, p2):
        dx = p1['x']-p2['x']
        dy = p1['y']-p2['y']

        return math.sqrt(dx*dx + dy*dy)
        
    a = sorted(a, key=cmp_to_key(compare))
    # print(a)
    
    b = [a[-1]]
    cp = a[-1]
    a.pop()

    while len(a):
        final_ideal = {'x': 0, 'y': 0}
        final_ideal_m = 0
        
        first_pos = {'x': 0, 'y': 0}
        first_pos_m = 0
        
        final_found = False
        
        for m in range(1, 10+1):
            threshold = m*thresh_base
            ideal = {'x': 0, 'y': 0}
            ideal_y, found = 0, False
            for p in a:
                if get_dist(cp, p) <= threshold:
                    if p['y'] > ideal_y:
                        ideal_y = p['y']
                        ideal = p
                        found = True
            if found:
                if not final_found:
                    final_ideal = ideal
                    final_ideal_m = m
                    final_found = True
                if ideal['y'] >= cp['y'] - error_y and not first_pos_m:
                    first_pos = ideal
                    first_pos_m = m
                    
        to_take = first_pos if first_pos_m else final_ideal
        
        if final_ideal['y'] >= first_pos['y']:
            to_take = final_ideal
        
        if not final_found or not len(a):
            break;
        while a[-1] != to_take:
            a.pop()
            
        cp = to_take
        b.append(to_take)
        a.pop()
        
    return b[::-1];

# %%
def get_boundary(a, n = 10):
    max_x = 0

    for p in a:
        max_x = max(max_x, p['x'])
        
    chunk =  max_x / n;
    best = [0 for i in range(n)]

    # filler = [{'x': 0, 'y': 0}]
    
    for p in a:
        h = min(n-1, math.floor(p['x'] / chunk))
        best[h] = max(best[h], p['y'])

    def non_zero(p):
        return p['y'] != 0
        
    ans = [{ 'x': float(chunk*i) + chunk / 2, 'y': best[i] } for i in range(n)]

    fx = -chunk / 2
    lx = 1 + chunk / 2

    return [{'x': fx, 'y': 0}] + ans + [{'x': lx, 'y': 0}]

# %%
def auto_scale(a, n = 10):
    new_a = copy.deepcopy(a)
    
    min_x = min([p['x'] for p in a])
    min_y = min([p['y'] for p in a])

    for p in new_a:
        p['x'] -= min_x
        p['y'] -= min_y

    scale = max([p['x'] for p in new_a])

    for p in new_a:
        p['x'] /= scale
        p['y'] /= scale

    return new_a

# %%
crawl, climb, size, mass, count = '0.2', '0.2', '0', '0', 100
filename = get_filename(crawl, climb, size, mass, count)
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
_ = get_boundary(auto_scale(points))

# %%
def get_curvature(points):
    points = get_boundary(auto_scale(points), n)
    points = [np.array([p['x'], p['y'], 0]) for p in points]
    
    if len(points) < 3:
        return []

    tangs = np.diff(points, axis=0)
    curvs = []

    for i in range(len(tangs)-1):
        v1 = tangs[i]
        v2 = tangs[i+1]
        
        dotp = np.dot(v1, v2)
        prod_mag = np.linalg.norm(v1) * np.linalg.norm(v2)
        
        if prod_mag == 0:
            cos_theta = 1.0
        else:
            cos_theta = dotp / prod_mag
            
        curvature = 2 * (1 - cos_theta)

        cross_prod = v1[0] * v2[1] - v1[1] * v2[0]

        if cross_prod > 0:
           curvature *= -1
            
        curvs.append(curvature)
        
    return np.mean(curvs)

# %%
def display_curvature_array(points, n=10):
    points = get_boundary(auto_scale(points), n)
    points = [np.array([p['x'], p['y'], 0]) for p in points]
    
    if len(points) < 3:
        return []

    tangs = np.diff(points, axis=0)
    curvs = []

    for i in range(len(tangs)-1):
        v1 = tangs[i]
        v2 = tangs[i+1]
        
        dotp = np.dot(v1, v2)
        prod_mag = np.linalg.norm(v1) * np.linalg.norm(v2)
        
        if prod_mag == 0:
            cos_theta = 1.0
        else:
            cos_theta = dotp / prod_mag
            
        curvature = 2 * (1 - cos_theta)

        cross_prod = v1[0] * v2[1] - v1[1] * v2[0]

        if cross_prod > 0:
           curvature *= -1
            
        curvs.append(curvature)
        
    rows = []
    
    for x in range(len(curvs)):
        rows.append([x/(len(curvs)-1), curvs[x]])
        
    df = pd.DataFrame(rows, columns=['x', 'y'])
    main_color = '#222222'
    saturation_scale = 4
    
    df['shade'] = df['y'].apply(lambda y: 1 if y > 0 else 0)
    df['saturation'] = df['y'].apply(lambda y: abs(y) / saturation_scale + 0.2)

    fig, ax = plt.subplots(figsize=(7, 6))

    ax.plot(df['x'], df['y'], color=main_color, linewidth=1, zorder=1)
    norm_original = Normalize(vmin=0.0, vmax=1.0)

    df_p = df[df['shade'] == 1]
    scatter_p = ax.scatter(
        df_p['x'],
        df_p['y'],
        c=df_p['saturation'],
        cmap='Greens',
        s=200 * df_p['saturation'],
        zorder=2,
        linewidth=1,
        edgecolor=main_color,
        norm=norm_original,
    )

    df_n = df[df['shade'] == 0]
    scatter_n = ax.scatter(
        df_n['x'],
        df_n['y'],
        c=df_n['saturation'],
        cmap='Reds',
        s=200 * df_n['saturation'],
        zorder=2,
        linewidth=1,
        edgecolor=main_color,
        norm=norm_original,
    )
    
    ax.set_xlim([-0.1, 1.1])
    ax.set_ylim([-2, 2])

    plt.show()

# %%
crawl, climb, size, mass, count = '0.4', '0.4', '0', '0', 300
filename = get_filename(crawl, climb, size, mass, count)
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display_curvature_array(points, 10)

# %%
display(points, 20, count/100*0.2 + 1)
# Out:
# Curvature: 0.2997

# %% [markdown]
# ### **Gallery**

# %%
count, size, mass = '200', '0', '0'
crawls = ['0', '0.2', '0.4', '0.6', '0.8', '1']
climbs = ['0', '0.2', '0.4', '0.6', '0.8', '1']
for crawl in crawls:
    for climb in climbs:
        filename = get_filename(crawl, climb, size, mass, count)
        with open(filename, 'r') as file:
            data = json.load(file)
        points = data['points']
        print(f'crawl: {crawl}, climb {climb}')
        display_curvature_array(points)
# Out:
# crawl: 0, climb 0
# crawl: 0, climb 0.2
# crawl: 0, climb 0.4
# crawl: 0, climb 0.6
# crawl: 0, climb 0.8
# crawl: 0, climb 1
# crawl: 0.2, climb 0
# crawl: 0.2, climb 0.2
# crawl: 0.2, climb 0.4
# crawl: 0.2, climb 0.6
# crawl: 0.2, climb 0.8
# crawl: 0.2, climb 1
# crawl: 0.4, climb 0
# crawl: 0.4, climb 0.2
# crawl: 0.4, climb 0.4
# crawl: 0.4, climb 0.6
# crawl: 0.4, climb 0.8
# crawl: 0.4, climb 1
# crawl: 0.6, climb 0
# crawl: 0.6, climb 0.2
# crawl: 0.6, climb 0.4
# crawl: 0.6, climb 0.6
# crawl: 0.6, climb 0.8
# crawl: 0.6, climb 1
# crawl: 0.8, climb 0
# crawl: 0.8, climb 0.2
# crawl: 0.8, climb 0.4
# crawl: 0.8, climb 0.6
# crawl: 0.8, climb 0.8
# crawl: 0.8, climb 1
# crawl: 1, climb 0
# crawl: 1, climb 0.2
# crawl: 1, climb 0.4
# crawl: 1, climb 0.6
# crawl: 1, climb 0.8
# crawl: 1, climb 1

# %%
def display(points, n=10, scale=1):
    ch_points = get_boundary(points, n)
    
    # y_thresh = 20
    
    # min_x = min(point['x'] for point in data['points'] if point['y'] < y_thresh)
    # max_x = max(point['x'] for point in data['points'] if point['y'] < y_thresh)
    
    # ch_points = list(filter(lambda pt: pt['y'] >= y_thresh or pt['x'] <= min_x or pt['x'] >= max_x, ch_points))
    
    np_points = [np.array([p['x'], p['y'], 0]) for p in ch_points]
    print(f"Curvature: {get_curvature(np_points):.4f}")
    
    rows = []

    max_x = max([point['x'] for point in data['points']])
    min_x = min([point['x'] for point in data['points']])
    
    halved = (max_x + min_x) / 2
    
    for i in range(len(points)):
        on_hull = False
        if points[i] in ch_points:
            on_hull = True
        rows.append([points[i]['x']-halved, -points[i]['y'], 'Yes' if on_hull else 'No'])
        
    df = pd.DataFrame(rows, columns=['x', 'y', 'On Hull'])
    
    rows = [];
    offset = (ch_points[1]['x'] - ch_points[0]['x'])/2
    
    for i in range(len(ch_points)):
        rows.append([ch_points[i]['x']-halved+offset, -ch_points[i]['y'], 'Yes'])
    
    df_hull = pd.DataFrame(rows, columns=['x', 'y', 'On Hull'])

    palette_duo = ["#678c2a", "#98cd9f"]

    first_no = df['On Hull'][0] == 'No'
    
    if first_no:
        palette_duo = palette_duo[::-1]
    
    plt.figure(figsize=(6, 4))
    
    # ax = sns.scatterplot(x='x', y='y', data=df, hue='On Hull', palette=palette_duo, legend=False, alpha=0.8, size=4)
    # sns.lineplot(x='x', y='y', data=df_hull, c=palette_duo[1] if first_no else palette_duo[0], alpha=0.8, size=4, linestyle='--', legend=False, sort=False)

    ax = sns.scatterplot(x='x', y='y', data=df, c=palette_duo[0], legend=False, alpha=0.8, size=4)
    sns.lineplot(x='x', y='y', data=df_hull, c=palette_duo[1], alpha=0.8, size=4, linestyle='--', legend=False, marker='o')
    
    ax.set_xlim([-500*scale, 500*scale])
    ax.set_ylim([-333*scale, 0])
    
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    
    ax.set(xlabel=None)
    ax.set(ylabel=None)
    
    plt.show()

# %%
crawl, climb, size, mass, count = '0.2', '1', '0', '0', 100
filename = get_filename(crawl, climb, size, mass, count)
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display(points)
# Out:
# Curvature: 0.4458

# %% [markdown]
# ### **Timelapse...**

# %%
crawl, climb, size, mass, count = '0.4', '0.4', '0', '0', 50
filename = get_filename(crawl, climb, size, mass, count)
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display(points)
# Out:
# Curvature: 0.1486

# %%
crawl, climb, size, mass, count = '0.4', '0.4', '0', '0', 100
filename = get_filename(crawl, climb, size, mass, count)
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display(points)
# Out:
# Curvature: 0.1515

# %%
crawl, climb, size, mass, count = '0.4', '0.4', '0', '0', 150
filename = get_filename(crawl, climb, size, mass, count)
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display(points)
# Out:
# Curvature: 0.1324

# %%
crawl, climb, size, mass, count = '0.4', '0.4', '0', '0', 200
filename = get_filename(crawl, climb, size, mass, count)
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display(points)
# Out:
# Curvature: 0.0762

# %% [markdown]
# ### **Gallery**

# %%
count, size, mass = '200', '0', '0'
crawls = ['0', '0.2', '0.4', '0.6', '0.8', '1']
climbs = ['0', '0.2', '0.4', '0.6', '0.8', '1']
for crawl in crawls:
    for climb in climbs:
        filename = get_filename(crawl, climb, size, mass, count)
        with open(filename, 'r') as file:
            data = json.load(file)
        points = data['points']
        print(f'crawl: {crawl}, climb {climb}')
        display(points, 20, int(count)/100*0.2 + 1)
# Out:
# crawl: 0, climb 0
# Curvature: 0.0616
# crawl: 0, climb 0.2
# Curvature: 0.0363
# crawl: 0, climb 0.4
# Curvature: 0.0667
# crawl: 0, climb 0.6
# Curvature: 0.0800
# crawl: 0, climb 0.8
# Curvature: 0.1481
# crawl: 0, climb 1
# Curvature: 0.2002
# crawl: 0.2, climb 0
# Curvature: 0.0548
# crawl: 0.2, climb 0.2
# Curvature: 0.0734
# crawl: 0.2, climb 0.4
# Curvature: 0.0856
# crawl: 0.2, climb 0.6
# Curvature: 0.1851
# crawl: 0.2, climb 0.8
# Curvature: 0.1536
# crawl: 0.2, climb 1
# Curvature: 0.1807
# crawl: 0.4, climb 0
# Curvature: 0.0308
# crawl: 0.4, climb 0.2
# Curvature: 0.0502
# crawl: 0.4, climb 0.4
# Curvature: 0.0762
# crawl: 0.4, climb 0.6
# Curvature: 0.1124
# crawl: 0.4, climb 0.8
# Curvature: 0.1704
# crawl: 0.4, climb 1
# Curvature: 0.1682
# crawl: 0.6, climb 0
# Curvature: 0.0888
# crawl: 0.6, climb 0.2
# Curvature: 0.0994
# crawl: 0.6, climb 0.4
# Curvature: 0.1936
# crawl: 0.6, climb 0.6
# Curvature: 0.1636
# crawl: 0.6, climb 0.8
# Curvature: 0.2161
# crawl: 0.6, climb 1
# Curvature: 0.1803
# crawl: 0.8, climb 0
# Curvature: 0.0912
# crawl: 0.8, climb 0.2
# Curvature: 0.0784
# crawl: 0.8, climb 0.4
# Curvature: 0.1387
# crawl: 0.8, climb 0.6
# Curvature: 0.1093
# crawl: 0.8, climb 0.8
# Curvature: 0.2386
# crawl: 0.8, climb 1
# Curvature: 0.2312
# crawl: 1, climb 0
# Curvature: 0.0916
# crawl: 1, climb 0.2
# Curvature: 0.1063
# crawl: 1, climb 0.4
# Curvature: 0.0883
# crawl: 1, climb 0.6
# Curvature: 0.1203
# crawl: 1, climb 0.8
# Curvature: 0.1664
# crawl: 1, climb 1
# Curvature: 0.1772
