# %%
import json
import scipy
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from functools import cmp_to_key

sns.set_theme(font='Fira Code', font_scale=0.8, style='whitegrid')
sns.set_style({'grid.linestyle': ':'})

# %%
def get_filename(crawl, climb, size, mass, count):
    return f'../data/crawl_{crawl}_climb_{climb}_size_{size}_mass_{mass}_cnt_{count}.json';

# %%
crawl, climb, size, mass, count = '0.2', '0.2', '0', '0', 100
filename = get_filename(crawl, climb, size, mass, count)
with open(filename, 'r') as file:
        data = json.load(file)
points = data['points']

# %%
def equal(a, b):
    return a['x'] == b['x'] and a['y'] == b['y']

# %%
def orientation(a, b, c):
    v = a['x']*(b['y']-c['y']) + b['x']*(c['y']-a['y']) + c['x']*(a['y']-b['y'])
    if v < 0:
        return -1
    if v > 0:
        return 1
    return 0;

# %%
def cw(a, b, c):
    return orientation(a, b, c) < 0

# %%
def convex_hull(a):
    p0 = a[0]
    
    for pt in a:
        if pt['y'] > p0['y']:
            continue;
        if pt['y'] == p0['y']:
            p0['x'] = min(p0['x'], pt['x'])
        else:
            p0 = pt
            
    def compare(a, b):
        o = orientation(p0, a, b)
        if o == 0:
            l = (p0['x']-a['x'])*(p0['x']-a['x']) + (p0['y']-a['y'])*(p0['y']-a['y'])
            r = (p0['x']-b['x'])*(p0['x']-b['x']) + (p0['y']-b['y'])*(p0['y']-b['y'])
            return l - r
        return -1 if o < 0 else 1
        
    a = sorted(a, key=cmp_to_key(compare))
    st = []
    
    for pt in a:
        while len(st) >= 2 and not cw(st[-2], st[-1], pt):
            st.pop()
        st.append(pt)
        
    if len(st) == 2 and st[0] == st[1]:
        st.pop()
        
    return st[::]

# %%
def display_ch(points):
    ch_points = convex_hull(points)
    
    y_thresh = 20
    
    min_x = min(point['x'] for point in data['points'] if point['y'] < y_thresh)
    max_x = max(point['x'] for point in data['points'] if point['y'] < y_thresh)
    
    ch_points = list(filter(lambda pt: pt['y'] >= y_thresh or pt['x'] <= min_x or pt['x'] >= max_x, ch_points))

    rows = []

    max_x = max([point['x'] for point in data['points']])
    min_x = min([point['x'] for point in data['points']])
    
    halved = (max_x + min_x) / 2
    
    for i in range(len(points)):
        on_hull = False
        if points[i] in ch_points:
            on_hull = True
        rows.append([points[i]['x']-halved, -points[i]['y'], 'Yes' if on_hull else 'No'])
        
    df = pd.DataFrame(rows, columns=['x', 'y', 'On Hull'])
    
    rows = [];
    
    for i in range(len(ch_points)):
        rows.append([ch_points[i]['x']-halved, -ch_points[i]['y'], 'Yes'])
    
    df_hull = pd.DataFrame(rows, columns=['x', 'y', 'On Hull'])

    palette_duo = ["#878c2a", "#c8cd9f"]

    first_no = df['On Hull'][0] == 'No'
    
    if first_no:
        palette_duo = palette_duo[::-1]
    
    plt.figure(figsize=(6, 4))
    ax = sns.scatterplot(x='x', y='y', data=df, hue='On Hull', palette=palette_duo, legend=False, alpha=0.8, size=4)
    sns.lineplot(x='x', y='y', data=df_hull, c=palette_duo[1] if first_no else palette_duo[0], alpha=0.8, size=4, linestyle='--', legend=False, sort=False)
    
    ax.set_xlim([-500, 500])
    ax.set_ylim([-333, 0])
    
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    
    ax.set(xlabel=None)
    ax.set(ylabel=None)
    
    plt.show()

# %%
crawl, climb, size, mass, count = '0.2', '0.2', '0', '0', 100
filename = get_filename(crawl, climb, size, mass, count)
with open(filename, 'r') as file:
        data = json.load(file)
points = data['points']
display_ch(points)

# %% [markdown]
# ### **Timelapse...**

# %%
crawl, climb, size, mass, count = '0.4', '0.4', '0', '0', 50
filename = get_filename(crawl, climb, size, mass, count)
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display_ch(points)

# %%
crawl, climb, size, mass, count = '0.4', '0.4', '0', '0', 100
filename = get_filename(crawl, climb, size, mass, count)
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display_ch(points)

# %%
crawl, climb, size, mass, count = '0.4', '0.4', '0', '0', 150
filename = get_filename(crawl, climb, size, mass, count)
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display_ch(points)

# %%
crawl, climb, size, mass, count = '0.4', '0.4', '0', '0', 200
filename = get_filename(crawl, climb, size, mass, count)
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display_ch(points)

# %%
crawl, climb, size, mass, count = '0.4', '0.4', '0', '0', 200
filename = get_filename(crawl, climb, size, mass, str(count)+'(1)')
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display_ch(points)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 crawl, climb, size, mass, count = '0.4', '0.4', '0', '0', 200
#       2 filename = get_filename(crawl, climb, size, mass, str(count)+'(1)')
# ----> 3 with open(filename, 'r') as file:
#       4     data = json.load(file)
#       5 points = data['points']
#
# File ~/python_environments/env_main/lib/python3.13/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/crawl_0.4_climb_0.4_size_0_mass_0_cnt_200(1).json'

# %%
crawl, climb, size, mass, count = '0.4', '0.4', '0', '0', 200
filename = get_filename(crawl, climb, size, mass, str(count)+'(2)')
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display_ch(points)

# %%
crawl, climb, size, mass, count = '0.4', '0.4', '0', '0', 200
filename = get_filename(crawl, climb, size, mass, str(count)+'(3)')
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display_ch(points)

# %%
crawl, climb, size, mass, count = '0.4', '0.4', '0', '0', 200
filename = get_filename(crawl, climb, size, mass, str(count)+'(4)')
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display_ch(points)

# %% [markdown]
# ### **Gallery**

# %%
count, size, mass = '100', '0', '0'
crawls = ['0', '0.2', '0.4', '0.6', '0.8', '1']
climbs = ['0', '0.2', '0.4', '0.6', '0.8', '1']
for crawl in crawls:
    for climb in climbs:
        filename = get_filename(crawl, climb, size, mass, count)
        with open(filename, 'r') as file:
            data = json.load(file)
        points = data['points']
        print(f'crawl: {crawl}, climb {climb}')
        display_ch(points)
# Out:
# crawl: 0, climb 0
# crawl: 0, climb 0.2
# crawl: 0, climb 0.4
# crawl: 0, climb 0.6
# crawl: 0, climb 0.8
# crawl: 0, climb 1
# crawl: 0.2, climb 0
# crawl: 0.2, climb 0.2
# crawl: 0.2, climb 0.4
# crawl: 0.2, climb 0.6
# crawl: 0.2, climb 0.8
# crawl: 0.2, climb 1
# crawl: 0.4, climb 0
# crawl: 0.4, climb 0.2
# crawl: 0.4, climb 0.4
# crawl: 0.4, climb 0.6
# crawl: 0.4, climb 0.8
# crawl: 0.4, climb 1
# crawl: 0.6, climb 0
# crawl: 0.6, climb 0.2
# crawl: 0.6, climb 0.4
# crawl: 0.6, climb 0.6
# crawl: 0.6, climb 0.8
# crawl: 0.6, climb 1
# crawl: 0.8, climb 0
# crawl: 0.8, climb 0.2
# crawl: 0.8, climb 0.4
# crawl: 0.8, climb 0.6
# crawl: 0.8, climb 0.8
# crawl: 0.8, climb 1
# crawl: 1, climb 0
# crawl: 1, climb 0.2
# crawl: 1, climb 0.4
# crawl: 1, climb 0.6
# crawl: 1, climb 0.8
# crawl: 1, climb 1

# %%
crawl, climb, size, mass, count = '0.2', '1', '0', '0', 100
filename = get_filename(crawl, climb, size, mass, str(count))
with open(filename, 'r') as file:
    data = json.load(file)
points = data['points']
display_ch(points)
